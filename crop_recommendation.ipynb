# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,classification_report,confusion_matrix
import joblib

# %%
data = pd.read_csv("dataset/Crop_recommendation.csv")
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %% [markdown]
# N - ratio of Nitrogen content in soil
#
# P - ratio of Phosphorous content in soil
#
# K - ratio of Potassium content in soil
#
# temperature - temperature in degree Celsius
#
# humidity - relative humidity in %
#
# ph - ph value of the soil
#
# rainfall - rainfall in mm

# %%
data.shape
# Out:
# (2200, 8)

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2195    False
# 2196    False
# 2197    False
# 2198    False
# 2199    False
# Length: 2200, dtype: bool

# %%
print(data['label'].nunique())
print(data['label'].value_counts())
# Out:
# 22
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %% [markdown]
# Class is Balanced

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
data.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
encoder = LabelEncoder()
data['label'] = encoder.fit_transform(data['label'])
data.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall  label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507      5
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610      5
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839      5
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293      5
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041      5

# %%
print(data['label'].nunique())
print(data['label'].value_counts())
# Out:
# 22
# label
# 20    100
# 11    100
# 8     100
# 6     100
# 4     100
# 17    100
# 16    100
# 0     100
# 15    100
# 21    100
# 7     100
# 12    100
# 1     100
# 19    100
# 10    100
# 2     100
# 14    100
# 13    100
# 18    100
# 9     100
# 3     100
# 5     100
# Name: count, dtype: int64

# %%
x = data.drop('label',axis=1)
y = data['label']

# %%
y.shape
# Out:
# (2200,)

# %%
for i in x.columns:
    sns.histplot(data[[i]],kde=True)
    plt.title(i)
    plt.show()

# %%
for i in x.columns:
    sns.boxplot(x[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# There are ouliers present but these can be realistic, so we should keep them

# %%
data[data['K']>180]
# Out:
#        N    P    K  temperature   humidity        ph    rainfall  label
# 1200  24  130  195    29.996772  81.541566  6.112306   67.125345      7
# 1201  13  144  204    30.728040  82.426141  6.092242   68.381355      7
# 1202  22  123  205    32.445778  83.885049  5.896343   68.739325      7
# 1203  36  125  196    37.465668  80.659687  6.155261   66.838723      7
# 1204  24  131  196    22.032962  83.743728  5.732454   65.344408      7
# ...   ..  ...  ...          ...        ...       ...         ...    ...
# 1595  40  120  197    23.805938  92.488795  5.889481  119.633555      0
# 1596  25  132  198    22.319441  90.851744  5.732758  100.117344      0
# 1597  31  137  196    22.144641  93.825674  6.400321  120.631078      0
# 1598  36  144  196    23.651676  94.505288  6.496934  115.361127      0
# 1599  10  140  197    22.169395  90.271856  6.229499  124.468311      0
#
# [200 rows x 8 columns]

# %%
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
y.head()
# Out:
# 0    20
# 1    20
# 2    20
# 3    20
# 4    20
# Name: label, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1760, 7)
# (1760,)
# (440, 7)
# (440,)

# %%
model = RandomForestClassifier(n_estimators=10,random_state=42,max_depth=20,min_samples_split=5)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_split=5, n_estimators=10,
#                        random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
f1 = f1_score(y_test,y_pred,average='weighted')

# %%
print(f1)
print(classification_report(y_test,y_pred))
cm = confusion_matrix(y_test,y_pred)
# Out:
# 0.9954229797979799
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        27
#            5       1.00      1.00      1.00        17
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        14
#            8       0.92      1.00      0.96        23
#            9       1.00      1.00      1.00        20
#           10       1.00      1.00      1.00        11
#           11       1.00      1.00      1.00        21
#           12       1.00      1.00      1.00        19
#           13       1.00      1.00      1.00        24
#           14       1.00      1.00      1.00        19
#           15       1.00      1.00      1.00        17
# ...

# %%
print(model.score(x_train,y_train))
print(model.score(x_test,y_test))
# Out:
# 0.9994318181818181
# 0.9954545454545455

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
scores = cross_val_score(model, x, y, cv=5, scoring='f1_macro')
print(scores)
print(scores.mean())
# Out:
# [0.98861216 0.993169   0.99544315 0.99772585 0.98399766]
# 0.9917895655776388

# %%
selected_features = x.columns.tolist()
print(selected_features)
# Out:
# ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

# %%
joblib.dump(model,'D:\AI Learning\Crop_recommendation\model\crop_recommendation.pkl')
joblib.dump(encoder,'D:\AI Learning\Crop_recommendation\model\encoder.pkl')
joblib.dump(selected_features,'D:\\AI Learning\\Crop_recommendation\\model\\features.pkl')
# Out:
# ['D:\\AI Learning\\Crop_recommendation\\model\\features.pkl']
